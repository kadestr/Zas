# %%
Frequentie =[25.64, 49.46, 66.23, 84.52, 96.81, 197.8, 308.0, 466.6, 635.0, 885.1, 2198, 4453, 6257, 7797, 9217]
amplitudes = [11.96, 11.80, 11.24, 10.64, 10.28, 7.280, 5.400, 3.760, 2.800, 2.080, 0.880, 0.450, 0.340, 0.300, 0.280]
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.semilogx(Frequentie, amplitudes, marker='o', linestyle='-', color='b')
plt.xlabel('Frequentie (Hz)')
plt.ylabel('Amplitude (V)')
plt.title('Frequentierespons van een RC-keten')    
plt.grid(True, which="both", ls="--")
plt.show()
